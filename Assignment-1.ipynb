# %%
import pandas as pd # importing the pandas library
data = pd.read_csv("Datasets/melb_data.csv") # reading the csv file using pandas
data # display
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...         1  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...         1  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...         2  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...         2  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...         1  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  int32
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
isNull = pd.isna(data["BuildingArea"])
isNull
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 13575     True
# 13576    False
# 13577     True
# 13578    False
# 13579    False
# Name: BuildingArea, Length: 13580, dtype: bool

# %%
isNull.dtypes
# Out:
# dtype('bool')

# %%
data.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
data.shape
# Out:
# (13580, 21)

# %%
data.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
val = data[data['Car']>2.0]
val.sort_values(by='Car')
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 7829        Fawkner      29 Jennifer St      3    h   741000.0      S
# 8093   Moonee Ponds      31 Pattison St      4    h  1531000.0      S
# 8097   Moonee Ponds      99 Eglinton St      4    h  1940000.0     PI
# 8100   Moonee Ponds     109 Waverley St      4    h  1515000.0      S
# 8110   Moonee Ponds        25 George St      4    h   955000.0      S
# ...             ...                 ...    ...  ...        ...    ...
# 3940    Maribyrnong      12 Newstead St      4    h  1900000.0     VB
# 8963   Surrey Hills  1093 Riversdale Rd      3    h  2100000.0     VB
# 11642     Dandenong  1462 Heatherton Rd      3    h   880000.0      S
# 9423      Bayswater        95 Orange Gr      4    h   925000.0     SP
# 13527     Reservoir            1 Don St      4    h  1112000.0      S
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom   Car  \
# ...

# %%
cars = data["Car"]
cars.describe()
# Out:
# count    13518.000000
# mean         1.610075
# std          0.962634
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max         10.000000
# Name: Car, dtype: float64

# %%
data['Bathroom'].astype('int64').dtypes
# Out:
# dtype('int64')

# %%
data['Bathroom'] = data['Bathroom'].astype('int')
data.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom           int32
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
data['Bathroom']
# Out:
# 0        1
# 1        1
# 2        2
# 3        2
# 4        1
#         ..
# 13575    2
# 13576    2
# 13577    2
# 13578    1
# 13579    1
# Name: Bathroom, Length: 13580, dtype: int32

# %%
data.iloc[9:25,2:15]
# Out:
#     Rooms Type      Price Method  SellerG        Date  Distance  Postcode  \
# 9       2    h  1097000.0      S   Biggin   8/10/2016       2.5    3067.0
# 10      2    u   700000.0     VB   Jellis  12/11/2016       2.5    3067.0
# 11      3    h  1350000.0     VB   Nelson  12/11/2016       2.5    3067.0
# 12      2    u   750000.0      S   Biggin  12/11/2016       2.5    3067.0
# 13      2    h  1172500.0      S   Biggin  13/08/2016       2.5    3067.0
# 14      1    u   441000.0     SP     Greg  14/05/2016       2.5    3067.0
# 15      2    h  1310000.0      S   Jellis  15/10/2016       2.5    3067.0
# 16      3    h  1200000.0      S   Jellis  16/07/2016       2.5    3067.0
# 17      3    h  1176500.0      S   LITTLE  16/07/2016       2.5    3067.0
# 18      3    h   955000.0      S  Collins  17/09/2016       2.5    3067.0
# 19      2    h   890000.0      S   Biggin  17/09/2016       2.5    3067.0
# 20      4    h  1330000.0     PI      Kay  18/03/2017       2.5    3067.0
# ...

# %%
data['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
data['Type'].unique()
# Out:
# array(['h', 'u', 't'], dtype=object)

# %%
data['Type'].replace(['h','u','t'],[0,1,2])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 13575    0
# 13576    0
# 13577    0
# 13578    0
# 13579    0
# Name: Type, Length: 13580, dtype: int64

# %%
data['Method'].replace(['S','SP','PI','VB','SA'],[0,1,2,3,4],inplace=True)

# %%
data
# Out:
#               Suburb           Address  Rooms Type      Price  Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0       0
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0       0
# 2         Abbotsford      5 Charles St      3    h  1465000.0       1
# 3         Abbotsford  40 Federation La      3    h   850000.0       2
# 4         Abbotsford       55a Park St      4    h  1600000.0       3
# ...              ...               ...    ...  ...        ...     ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0       0
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0       1
# 13577   Williamstown       83 Power St      3    h  1170000.0       0
# 13578   Williamstown      96 Verdon St      4    h  2500000.0       2
# 13579     Yarraville        6 Agnes St      4    h  1285000.0       1
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...
