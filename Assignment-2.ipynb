# %% [markdown]
# Chinmay Ambekar Class: TE4 (K4) Roll No: 31403

# %% [markdown]
# # Assignment 2

# %% [markdown]
# # Data Wrangling ||

# %%
# importing the modules
import pandas as pd
import numpy as np

# %%
# reading the data set 
data = pd.read_csv('Datasets/StudentsPerformance.csv')
df = data.copy() # copying the dataset into df
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# To display the number of rows and columns in the dataset
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   957 non-null    float64
#  6   reading score                994 non-null    float64
#  7   writing score                991 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 62.6+ KB

# %%
# To get the statistical information about the dataset
df.describe()
# Out:
#        math score  reading score  writing score
# count  957.000000     994.000000     991.000000
# mean    66.323929      68.008048      69.487386
# std     18.280119      16.602270      29.563757
# min    -89.000000       3.000000      10.000000
# 25%     57.000000      58.000000      57.000000
# 50%     66.000000      69.500000      69.000000
# 75%     77.000000      79.000000      79.000000
# max    334.000000     100.000000     567.000000

# %%
# To check the number of null values in each column
df.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     43
# reading score                   6
# writing score                   9
# dtype: int64

# %%
# To check the data type of each column
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# To get the unique values from the columns of type "object"
col_len = len(df.columns)
for i in range(col_len-3):
    print(df.iloc[:,i].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ['standard' 'free/reduced']
# ['none' 'completed']

# %%
# Filling the NA values with the mean of the columns
math_score_mean = df['math score'].mean()
df['math score'].fillna(math_score_mean, inplace = True)

# %%
# Filling the NA values with the mean of the columns
reading_score_mean = df['reading score'].mean()
df['reading score'].fillna(reading_score_mean, inplace = True)

# %%
# Filling the NA values with the mean of the columns
writing_score_mean = df['writing score'].mean()
df['writing score'].fillna(writing_score_mean, inplace = True)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # Converting Categorical data into Numerical data

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df['gender'].replace(['female','male'],[0,1],inplace=True)

# %%
df['race/ethnicity'].replace(['group A', 'group B', 'group C', 'group D', 'group E'],[0,1,2,3,4],inplace=True)

# %%
df['parental level of education'].replace(["bachelor's degree", 'some college', "master's degree", "associate's degree",
 'high school', 'some high school'],[0,1,2,3,4,5],inplace=True)

# %%
df['lunch'].replace(['standard', 'free/reduced'],[0,1],inplace=True)

# %%
df['test preparation course'].replace(['none', 'completed'],[0,1],inplace=True)

# %%
df.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0       0               1                            0      0
# 1       0               2                            1      0
# 2       0               1                            2      0
# 3       1               0                            3      1
# 4       1               2                            1      0
#
#    test preparation course  math score  reading score  writing score
# 0                        0        72.0           72.0           74.0
# 1                        1        69.0           90.0           88.0
# 2                        0        90.0           95.0           93.0
# 3                        0        47.0           57.0           44.0
# 4                        0        76.0           78.0           75.0

# %% [markdown]
# # Detecting and Removing Outliers

# %%
import seaborn as sns
sns.boxplot(data['math score'])

# %%
sns.boxplot(data['reading score'])

# %%
sns.boxplot(data['writing score'])

# %%
df_test = df.copy()
df_test.describe()
# Out:
#             gender   math score  reading score  writing score
# count  1000.000000  1000.000000    1000.000000    1000.000000
# mean      0.482000    66.323929      68.008048      69.487386
# std       0.499926    17.882376      16.552339      29.430286
# min       0.000000   -89.000000       3.000000      10.000000
# 25%       0.000000    57.000000      58.000000      58.000000
# 50%       0.000000    66.323929      69.000000      69.000000
# 75%       1.000000    76.000000      79.000000      79.000000
# max       1.000000   334.000000     100.000000     567.000000

# %%
q1 = df_test['math score'].quantile(0.25)
q3 = df_test['math score'].quantile(0.75)
iqr = q3-q1
lower = q1-1.5*iqr
upper = q3+1.5*iqr
# outlier values
# df_test[(df_test['math score']<lower) | (df_test['math score']>upper)]

# After removal of outliers
df_test[(df_test['math score']>lower) & (df_test['math score']<upper)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59        0        group C            some high school  free/reduced
# 91        1        group C                 high school  free/reduced
# 145       0        group C                some college  free/reduced
# 327       1        group A                some college  free/reduced
# 338       0        group B            some high school  free/reduced
# 363       0        group D            some high school  free/reduced
# 420       0        group C          associate's degree  free/reduced
# 431       0        group C                 high school      standard
# 456       0        group D           bachelor's degree      standard
# 466       0        group D          associate's degree  free/reduced
# 474       0        group B          associate's degree      standard
# 787       0        group B                some college      standard
# 842       0        group B                 high school  free/reduced
# ...

# %%
q1 = df_test['reading score'].quantile(0.25)
q3 = df_test['reading score'].quantile(0.75)
iqr = q3-q1
lower = q1-1.5*iqr
upper = q3+1.5*iqr
# outlier values
# df_test[(df_test['math score']<lower) | (df_test['math score']>upper)]

# After removal of outliers
df_test[(df_test['reading score']>lower) & (df_test['reading score']<upper)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         0        group B           bachelor's degree      standard
# 1         0        group C                some college      standard
# 2         0        group B             master's degree      standard
# 3         1        group A          associate's degree  free/reduced
# 4         1        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       0        group E             master's degree      standard
# 996       1        group C                 high school  free/reduced
# 997       0        group C                 high school  free/reduced
# 998       0        group D                some college      standard
# 999       0        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
q1 = df_test['writing score'].quantile(0.25)
q3 = df_test['writing score'].quantile(0.75)
iqr = q3-q1
lower = q1-1.5*iqr
upper = q3+1.5*iqr
# outlier values
# df_test[(df_test['math score']<lower) | (df_test['math score']>upper)]

# After removal of outliers
# df_test[(df_test['writing score']>lower) & (df_test['writing score']<upper)]
df_copy = df_test.copy()
df_drop = df_copy.drop(df_copy[(df_copy['writing score'] < lower)].index)
df_drop
# df_drop.head(92)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         0        group B           bachelor's degree      standard
# 1         0        group C                some college      standard
# 2         0        group B             master's degree      standard
# 3         1        group A          associate's degree  free/reduced
# 4         1        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       0        group E             master's degree      standard
# 996       1        group C                 high school  free/reduced
# 997       0        group C                 high school  free/reduced
# 998       0        group D                some college      standard
# 999       0        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_copy.shape
# Out:
# (1000, 8)

# %%
# columns having the data type as "float64"
cols = df_test.select_dtypes(['float64']).columns
cols
# Out:
# Index(['math score', 'reading score', 'writing score'], dtype='object')

# %%
# IQR value for math, writing and reading columns
from scipy import stats
dft = df_test.copy()
result = stats.iqr(dft[cols], axis = 0)
result
# Out:
# array([19., 21., 21.])

# %%
dft.shape
# Out:
# (1000, 8)

# %%
dft.drop(dft[dft['math score'] < (dft['math score'].quantile(0.25) - 1.5 * result[0])].index, inplace = True)
dft.drop(dft[dft['reading score'] < (dft['reading score'].quantile(0.25) - 1.5 * result[1])].index, inplace = True)
dft.drop(dft[dft['writing score'] < (dft['writing score'].quantile(0.25) - 1.5 * result[2])].index, inplace = True)

# %%
dft.shape
# Out:
# (968, 8)

# %% [markdown]
# # Scaling data from range 0 to 10

# %%
df_scaled = dft.copy()
features = df_scaled[cols]

# %%
# Using MinMaxScaler to scale in between 0 to 10.
from sklearn.preprocessing import MinMaxScaler
# scale = (x - min) / (max - min)

scaler = MinMaxScaler(feature_range = (0, 10))
df_scaled[cols] = scaler.fit_transform(features.values)

# %%
df_scaled.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       0        group B           bachelor's degree      standard
# 1       0        group C                some college      standard
# 2       0        group B             master's degree      standard
# 3       1        group A          associate's degree  free/reduced
# 4       1        group C                some college      standard
# 5       0        group B          associate's degree      standard
# 6       0        group B                some college      standard
# 7       1        group B                some college  free/reduced
# 8       1        group D                 high school  free/reduced
# 9       0        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none    1.409836       6.111111       0.870370
# 1               completed    1.311475       8.611111       1.129630
# ...
